# %%
abc= {
    "Bilal": "saeed",
    "Ali": "Abdullah",
    "Saeed": "Ahmed"
}
print(abc)
# Out:
# {'Bilal': 'saeed', 'Ali': 'Abdullah', 'Saeed': 'Ahmed'}

# %%
abc["Bilal"]="Ahmed"

# %%
print(abc)
# Out:
# {'Bilal': 'Ahmed', 'Ali': 'Abdullah', 'Saeed': 'Ahmed'}

# %%
thisdict =	dict(apple="green", banana="yellow", cherry="red")
# note that keywords are not string literals
# note the use of equals rather than colon for the assignment
print(thisdict)
# Out:
# {'apple': 'green', 'banana': 'yellow', 'cherry': 'red'}

# %%
a=dict(b="a",c="2",d=4)
print(a)
# Out:
# {'b': 'a', 'c': '2', 'd': 4}

# %%
del(a["c"])
print(a)
# Out:
# {'b': 'a', 'd': 4}

# %%
a["Bilal"]="SAeed"
print(a)
# Out:
# {'b': 'a', 'd': 4, 'Bilal': 'SAeed'}

# %%
a=0
b=0

if a > b:
    print("This is wrong!!!!!!")
elif a==b:
    print("This  totally sucks")
elif a<=b:
    print("Thats right")
else:
    print("Nothing hppened")
# Out:
# This  totally sucks

# %%
a="Hello"

# %%
print(a)
# Out:
# Hello

# %%
4
# Out:
# 4

# %%
i=0
while i<10:
    print(i)
    if i==4:
        break
    i +=2
# Out:
# 0
# 2
# 4

# %%
# Out:
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# HEllO
# 0
# ...

# %%
i = 0
while i < 6:
    i += 1
    print(i)
    if i == 3:
        continue
        print("Bilal")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
abc=[1,2,34,5,66,7,8,"Bilal","Saeed"]

# %%
print(abc)
# Out:
# [1, 2, 34, 5, 66, 7, 8, 'Bilal', 'Saeed']

# %%
for b in abc:
    if b == 33:
        break
    print(b)
else:
    print("We failed to found the respective number")
# Out:
# 1
# 2
# 34
# 5
# 66
# 7
# 8
# Bilal
# Saeed
# We failed to found the respective number

# %%
for a in abc:
    if a == "Bilal":
        print("Hello World")
        continue
        
    print(a)
# Out:
# 1
# 2
# 34
# 5
# 66
# 7
# 8
# Hello World
# Saeed

# %%
for x in range(6):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2, 30, 3):
    print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
def tri_recursion(k):
    if(k>0):
        result = k+tri_recursion(k-1)
    print(result)
    else:
        result = 0
    return result

print("\n\nRecursion Example Results")
tri_recursion(6)
# Out:
#   File "<ipython-input-48-eaf689b6668f>", line 5
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
age=int(input("His age?: "))
city=input("Where did you see him last time: ")
if (age > 25 or age==20) and city=="Karachi":
    print()
    print("Found your man!!!!!!!!!!!")
    print("Bilal Saeed")
    print("section: A")
    print("008")
else:
    print("Sorry !! Didn't got what you want")
# Out:
# His age?: 32
# Where did you see him last time: Karachi
#
# Found your man!!!!!!!!!!!
# Bilal Saeed
# section: A
# 008

# %%
x=1
y=1
a=2
b=5
c=2 
d= 2
if (x == y or a == b) and c == d: 
    g = 'h' 
else:
     e = f

# %%
g
# Out:
# 'h'
